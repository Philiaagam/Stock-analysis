# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt, seaborn as sns

# %%
# Load all 4 datasets 
company_info = pd.read_csv("../data/raw/company_info.csv")
market_indices = pd.read_csv("../data/raw/market_indices.csv")
stock_prices = pd.read_csv("../data/raw/stock_prices.csv")
stock_prices_indicators = pd.read_csv("../data/raw/stock_prices_with_indicators.csv")
print (" All CSVc loaded successfully (if no errors shown).")
# Out:
#  All CSVc loaded successfully (if no errors shown).

# %%
datasets = {
    "company_info": company_info,
    "market_indices": market_indices,
    "stock_prices": stock_prices,
    "stock_prices_indicators": stock_prices_indicators
}

# %% [markdown]
# ### 1. Company_info dataset

# %%
company_info.shape
# Out:
# (20, 4)

# %%
company_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ticker        20 non-null     object
#  1   company_name  20 non-null     object
#  2   sector        20 non-null     object
#  3   ipo_date      20 non-null     object
# dtypes: object(4)
# memory usage: 772.0+ bytes

# %%
company_info.head()
# Out:
#    ticker company_name      sector    ipo_date
# 0  STK001     TechCorp  Technology  2021-04-10
# 1  STK002  DataSystems  Technology  2016-10-12
# 2  STK003    CloudNine  Technology  2016-01-18
# 3  STK004  CyberShield  Technology  2022-02-21
# 4  STK005    MediPharm  Healthcare  2018-03-05

# %% [markdown]
# #### Insight
# Company_Info dataset has 20 rows and 4 columns with no null values. This file help to map tickers to company names and sectors for grouping, filtering, and sector-based analysis.

# %% [markdown]
# ### 2. Market_Indices dataset

# %%
market_indices.shape
# Out:
# (780, 7)

# %%
market_indices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 780 entries, 0 to 779
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           780 non-null    object
#  1   sp500_close    780 non-null    float64
#  2   nasdaq_close   780 non-null    float64
#  3   vix_close      780 non-null    float64
#  4   treasury_10y   780 non-null    float64
#  5   dollar_index   780 non-null    float64
#  6   market_regime  780 non-null    object
# dtypes: float64(5), object(2)
# memory usage: 42.8+ KB

# %%
market_indices.head()
# Out:
#          date  sp500_close  nasdaq_close  vix_close  treasury_10y  \
# 0  2021-01-04      3891.04      12952.02      20.48         1.496
# 1  2021-01-05      3847.20      13116.52      19.89         1.504
# 2  2021-01-06      3878.24      12818.48      20.02         1.507
# 3  2021-01-07      3803.95      13290.11      19.59         1.498
# 4  2021-01-08      3715.64      13365.73      20.14         1.498
#
#    dollar_index market_regime
# 0         90.07          bull
# 1         90.73          bull
# 2         90.46          bull
# 3         90.67          bull
# 4         90.64          bull

# %% [markdown]
# #### Insight
# Market Indices has 780 rows and 7 columns with no null entires

# %% [markdown]
# ### 3. Stock_Prices dataset

# %%
stock_prices.shape
# Out:
# (15600, 8)

# %%
stock_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15600 entries, 0 to 15599
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ticker          15600 non-null  object
#  1   date            15600 non-null  object
#  2   open            15600 non-null  float64
#  3   high            15600 non-null  float64
#  4   low             15600 non-null  float64
#  5   close           15600 non-null  float64
#  6   volume          15600 non-null  int64
#  7   adjusted_close  15600 non-null  float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 975.1+ KB

# %%
stock_prices.head()
# Out:
#    ticker        date    open    high     low   close   volume  adjusted_close
# 0  STK001  2021-01-04  158.09  160.97  158.09  160.11   962644          160.11
# 1  STK001  2021-01-05  163.16  165.50  160.76  162.36  1312685          162.36
# 2  STK001  2021-01-06  161.89  162.51  160.94  161.78  1449177          161.78
# 3  STK001  2021-01-07  163.33  167.90  163.33  167.07  1534833          167.07
# 4  STK001  2021-01-08  168.20  168.20  164.12  165.68   848261          165.68

# %% [markdown]
# #### Insight
# Stock_prices dataset has 15600 rows and 8 columns with no null entires

# %% [markdown]
# ### 4. Stock_Prices_Indicators

# %%
stock_prices_indicators.shape
# Out:
# (15502, 31)

# %%
stock_prices_indicators.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15502 entries, 0 to 15501
# Data columns (total 31 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ticker            15502 non-null  object
#  1   date              15502 non-null  object
#  2   open              15502 non-null  float64
#  3   high              15502 non-null  float64
#  4   low               15502 non-null  float64
#  5   close             15502 non-null  float64
#  6   volume            15502 non-null  float64
#  7   adjusted_close    15502 non-null  float64
#  8   sma_20            15192 non-null  float64
#  9   sma_50            15502 non-null  float64
#  10  sma_200           15502 non-null  float64
#  11  ema_12            15502 non-null  float64
#  12  ema_26            15502 non-null  float64
#  13  macd              15191 non-null  float64
#  14  macd_signal       15502 non-null  float64
#  15  macd_histogram    15502 non-null  float64
#  16  rsi_14            15172 non-null  float64
#  17  bb_middle         15502 non-null  float64
#  18  bb_upper          15482 non-null  float64
#  19  bb_lower          15482 non-null  float64
#  20  bb_width          15171 non-null  float64
#  21  true_range        15502 non-null  float64
#  22  atr_14            15502 non-null  float64
#  23  volume_sma_20     15502 non-null  float64
#  24  volume_ratio      15192 non-null  float64
#  25  momentum_10       15302 non-null  float64
#  26  momentum_20       15102 non-null  float64
#  27  price_to_sma_50   15502 non-null  float64
#  28  volatility_20     15462 non-null  float64
#  29  future_return_5d  15502 non-null  float64
#  30  trend_label       15502 non-null  object
# dtypes: float64(28), object(3)
# memory usage: 3.7+ MB

# %%
stock_prices_indicators.head()
# Out:
#    ticker        date    open    high     low   close     volume  \
# 0  STK001  2021-01-04  158.09  160.97  158.09  160.11   962644.0
# 1  STK001  2021-01-05  163.16  165.50  160.76  162.36  1312685.0
# 2  STK001  2021-01-06  161.89  162.51  160.94  161.78  1449177.0
# 3  STK001  2021-01-07  163.33  167.90  163.33  167.07  1534833.0
# 4  STK001  2021-01-08  168.20  168.20  164.12  165.68   848261.0
#
#    adjusted_close      sma_20      sma_50  ...  true_range  atr_14  \
# 0          160.11  160.110000  160.110000  ...        2.88   2.880
# 1          162.36  161.235000  161.235000  ...        5.39   4.135
# 2          161.78  161.416667  161.416667  ...        1.57   3.280
# 3          167.07  162.830000  162.830000  ...        6.12   3.990
# 4          165.68  163.400000  163.400000  ...        4.08   4.008
#
#    volume_sma_20  volume_ratio  momentum_10  momentum_20  price_to_sma_50  \
# 0      962644.00      1.000000          NaN          NaN         0.000000
# 1     1137664.50      1.153842          NaN          NaN         0.006977
# 2     1241502.00      1.167277          NaN          NaN         0.002251
# 3     1314834.75      1.167320          NaN          NaN         0.026039
# 4     1221520.00      0.694431          NaN          NaN         0.013953
#
#    volatility_20  future_return_5d  trend_label
# 0            NaN          0.026357      Uptrend
# 1            NaN          0.018169     Sideways
# 2       0.012463         -0.012301     Sideways
# 3       0.018138         -0.061950    Downtrend
# 4       0.018663         -0.070196    Downtrend
#
# [5 rows x 31 columns]

# %% [markdown]
# #### Insight
# stock_prices_indicators has 15502 rows, 31 columns and some null values

# %%
total_missing = stock_prices_indicators.isnull().sum().sum()
total_cells = stock_prices_indicators.shape[0] * stock_prices_indicators.shape[1]
overall_missing_percent = (total_missing / total_cells) * 100

print(f"Overall missing percentage: {overall_missing_percent:.2f}%")
# Out:
# Overall missing percentage: 0.47%

# %%
stock_prices_indicators.head()
# Out:
#    ticker        date    open    high     low   close     volume  \
# 0  STK001  2021-01-04  158.09  160.97  158.09  160.11   962644.0
# 1  STK001  2021-01-05  163.16  165.50  160.76  162.36  1312685.0
# 2  STK001  2021-01-06  161.89  162.51  160.94  161.78  1449177.0
# 3  STK001  2021-01-07  163.33  167.90  163.33  167.07  1534833.0
# 4  STK001  2021-01-08  168.20  168.20  164.12  165.68   848261.0
#
#    adjusted_close      sma_20      sma_50  ...  true_range  atr_14  \
# 0          160.11  160.110000  160.110000  ...        2.88   2.880
# 1          162.36  161.235000  161.235000  ...        5.39   4.135
# 2          161.78  161.416667  161.416667  ...        1.57   3.280
# 3          167.07  162.830000  162.830000  ...        6.12   3.990
# 4          165.68  163.400000  163.400000  ...        4.08   4.008
#
#    volume_sma_20  volume_ratio  momentum_10  momentum_20  price_to_sma_50  \
# 0      962644.00      1.000000          NaN          NaN         0.000000
# 1     1137664.50      1.153842          NaN          NaN         0.006977
# 2     1241502.00      1.167277          NaN          NaN         0.002251
# 3     1314834.75      1.167320          NaN          NaN         0.026039
# 4     1221520.00      0.694431          NaN          NaN         0.013953
#
#    volatility_20  future_return_5d  trend_label
# 0            NaN          0.026357      Uptrend
# 1            NaN          0.018169     Sideways
# 2       0.012463         -0.012301     Sideways
# 3       0.018138         -0.061950    Downtrend
# 4       0.018663         -0.070196    Downtrend
#
# [5 rows x 31 columns]

# %%
stock_prices_indicators.sort_values("date", inplace=True)
stock_prices_indicators.ffill(inplace=True)
stock_prices_indicators.bfill(inplace=True)

# %%
stock_prices_indicators.head()
# Out:
#       ticker        date    open    high     low   close     volume  \
# 0     STK001  2021-01-04  158.09  160.97  158.09  160.11   962644.0
# 2325  STK004  2021-01-04  151.44  155.22  150.33  152.00   963623.0
# 3100  STK005  2021-01-04   89.08   90.46   88.01   89.70  1491126.0
# 3875  STK006  2021-01-04   84.61   85.19   82.84   84.13   954683.0
# 4650  STK007  2021-01-04   76.13   77.80   76.00   76.85   947006.0
#
#       adjusted_close  sma_20  sma_50  ...  true_range  atr_14  volume_sma_20  \
# 0             160.11  160.11  160.11  ...        2.88    2.88       962644.0
# 2325          152.00  152.00  152.00  ...        4.89    4.89       963623.0
# 3100           89.70   89.70   89.70  ...        2.45    2.45      1491126.0
# 3875           84.13   84.13   84.13  ...        2.35    2.35       954683.0
# 4650           76.85   76.85   76.85  ...        1.80    1.80       947006.0
#
#       volume_ratio  momentum_10  momentum_20  price_to_sma_50  volatility_20  \
# 0              1.0    -0.044552     0.156698              0.0       0.020763
# 2325           1.0    -0.044552     0.156698              0.0       0.020763
# 3100           1.0    -0.044552     0.156698              0.0       0.020763
# 3875           1.0    -0.044552     0.156698              0.0       0.020763
# 4650           1.0    -0.044552     0.156698              0.0       0.020763
#
#       future_return_5d  trend_label
# 0             0.026357      Uptrend
# 2325         -0.032829    Downtrend
# 3100         -0.011594     Sideways
# 3875          0.032093      Uptrend
# 4650          0.008068     Sideways
#
# [5 rows x 31 columns]

# %%
stock_prices_indicators.isnull().sum()
# Out:
# ticker              0
# date                0
# open                0
# high                0
# low                 0
# close               0
# volume              0
# adjusted_close      0
# sma_20              0
# sma_50              0
# sma_200             0
# ema_12              0
# ema_26              0
# macd                0
# macd_signal         0
# macd_histogram      0
# rsi_14              0
# bb_middle           0
# bb_upper            0
# bb_lower            0
# bb_width            0
# true_range          0
# atr_14              0
# volume_sma_20       0
# volume_ratio        0
# momentum_10         0
# momentum_20         0
# price_to_sma_50     0
# volatility_20       0
# future_return_5d    0
# trend_label         0
# dtype: int64

# %%
# Identify datatype mismatches 
for name, df in datasets.items():
    print(f"\n📘 Data Types in {name}")
    display(df.dtypes)
# Out:
# 📘 Data Types in company_info
# ticker          object
# company_name    object
# sector          object
# ipo_date        object
# dtype: object
# 📘 Data Types in market_indices
# date              object
# sp500_close      float64
# nasdaq_close     float64
# vix_close        float64
# treasury_10y     float64
# dollar_index     float64
# market_regime     object
# dtype: object
# 📘 Data Types in stock_prices
# ticker             object
# date               object
# open              float64
# high              float64
# low               float64
# close             float64
# volume              int64
# adjusted_close    float64
# dtype: object
# 📘 Data Types in stock_prices_indicators
# ticker               object
# date                 object
# open                float64
# high                float64
# low                 float64
# close               float64
# volume              float64
# adjusted_close      float64
# sma_20              float64
# sma_50              float64
# sma_200             float64
# ema_12              float64
# ema_26              float64
# macd                float64
# macd_signal         float64
# macd_histogram      float64
# rsi_14              float64
# bb_middle           float64
# bb_upper            float64
# bb_lower            float64
# bb_width            float64
# true_range          float64
# atr_14              float64
# volume_sma_20       float64
# volume_ratio        float64
# momentum_10         float64
# momentum_20         float64
# price_to_sma_50     float64
# volatility_20       float64
# future_return_5d    float64
# trend_label          object
# dtype: object

# %%
# Fixing object type for date columns 
for name, df in datasets.items():
    # Convert 'date' column if it exists
    if 'date' in df.columns:
        try:
            df['date'] = pd.to_datetime(df['date'], errors='coerce')
            print(f" Converted 'date' to datetime in {name}")
        except Exception as e:
            print(f" Error converting 'date' in {name}: {e}")
    
    # Convert 'ipo_date' column if it exists
    if 'ipo_date' in df.columns:
        try:
            df['ipo_date'] = pd.to_datetime(df['ipo_date'], errors='coerce')
            print(f" Converted 'ipo_date' to datetime in {name}")
        except Exception as e:
            print(f" Error converting 'ipo_date' in {name}: {e}")
# Out:
#  Converted 'ipo_date' to datetime in company_info
#  Converted 'date' to datetime in market_indices
#  Converted 'date' to datetime in stock_prices
#  Converted 'date' to datetime in stock_prices_indicators

# %%
# Check for duplicate 
for name, df in datasets.items():
    duplicates = df.duplicated().sum()
    print(f"{name}: {duplicates} duplicate rows")
# Out:
# company_info: 0 duplicate rows
# market_indices: 0 duplicate rows
# stock_prices: 0 duplicate rows
# stock_prices_indicators: 0 duplicate rows

# %%
missing_dates_report = []

for ticker in stock_prices_indicators['ticker'].unique():
    sample = stock_prices_indicators[stock_prices_indicators['ticker'] == ticker].sort_values('date')
    
    # Generate expected business-day range
    expected_dates = pd.date_range(sample['date'].min(), sample['date'].max(), freq='B')
    
    # Compare with actual dates
    missing_dates = expected_dates.difference(sample['date'])
    
    # Store result
    missing_dates_report.append({'ticker': ticker, 'missing_dates': len(missing_dates)})

# Convert to DataFrame for easy viewing
missing_dates_df = pd.DataFrame(missing_dates_report)
print(missing_dates_df)
# Out:
#     ticker  missing_dates
# 0   STK001              0
# 1   STK004              0
# 2   STK005              0
# 3   STK006              0
# 4   STK007              0
# 5   STK008              0
# 6   STK009              0
# 7   STK010              0
# 8   STK003              0
# 9   STK012              0
# 10  STK014              0
# 11  STK015              0
# 12  STK016              0
# 13  STK017              0
# 14  STK018              0
# 15  STK019              0
# 16  STK020              0
# 17  STK013              0
# 18  STK002              0
# 19  STK011              0

# %%
#  Verify date ranges and continuity in time-series data
for name, df in [("market_indices", market_indices),  ("stock_prices", stock_prices), ("stock_prices_indicators", stock_prices_indicators)]:
    if 'date' in df.columns:
        print(f"\n📅 {name} Date Range:")
        print("Start:", df['date'].min())
        print("End:", df['date'].max())
        print("Unique Dates:", df['date'].nunique())
# Out:
# 📅 market_indices Date Range:
# Start: 2021-01-04 00:00:00
# End: 2023-12-29 00:00:00
# Unique Dates: 780
#
# 📅 stock_prices Date Range:
# Start: 2021-01-04 00:00:00
# End: 2023-12-29 00:00:00
# Unique Dates: 780
#
# 📅 stock_prices_indicators Date Range:
# Start: 2021-01-04 00:00:00
# End: 2023-12-25 00:00:00
# Unique Dates: 776

# %% [markdown]
# ### Insight
# The first two datasets (market_indices and stock_prices) have the same:
#  1. Start and end dates
#  2. Total number of trading days (780)
# That means they cover the same full date range — perfect.
#
# But stock_prices_indicators ends on 2023-12-25, not 2023-12-29, and has 776 unique dates, i.e. 4 fewer days.
#
# What This Means?
#
# The indicator dataset is slightly shorter — it didn’t generate indicators (like moving averages or RSI) for the final few days.
# This is common because technical indicators (e.g., SMA, RSI, MACD) rely on rolling windows — the last few rows sometimes have missing values that get dropped during computation or cleaning.

# %%
# let align to the same date range 
full_range = pd.date_range('2021-01-04', '2023-12-29', freq='B')

aligned_data = []

for ticker, group in stock_prices_indicators.groupby('ticker'):
    group = (
        group.set_index('date')
        .reindex(full_range)
        .ffill()
        .reset_index()
        .rename(columns={'index': 'date'})
    )
    group['ticker'] = ticker
    aligned_data.append(group)

stock_prices_indicators = pd.concat(aligned_data, ignore_index=True)

# %%
#  confirm the date ranges alignment and continuity in time-series data
for name, df in [("market_indices", market_indices),  ("stock_prices", stock_prices), ("stock_prices_indicators", stock_prices_indicators)]:
    if 'date' in df.columns:
        print(f"\n📅 {name} Date Range:")
        print("Start:", df['date'].min())
        print("End:", df['date'].max())
        print("Unique Dates:", df['date'].nunique())
# Out:
# 📅 market_indices Date Range:
# Start: 2021-01-04 00:00:00
# End: 2023-12-29 00:00:00
# Unique Dates: 780
#
# 📅 stock_prices Date Range:
# Start: 2021-01-04 00:00:00
# End: 2023-12-29 00:00:00
# Unique Dates: 780
#
# 📅 stock_prices_indicators Date Range:
# Start: 2021-01-04 00:00:00
# End: 2023-12-29 00:00:00
# Unique Dates: 780

# %% [markdown]
# 🧾 **Data Quality Summary and Insights**
#
# | Dataset | Missing Values (%) | Key Fixes/Actions | Data Type Issues | Date Range | Insights |
# |----------|--------------------|------------------|------------------|-------------|-----------|
# | **company_info** | 0.00% | Converted `ipo_date` to datetime | Initially stored as object | N/A | Clean metadata for companies; ready for merging or reference use. |
# | **market_indices** | 0.00% | Converted `date` to datetime | Initially stored as object | 2021-01-04 → 2023-12-29 (780 unique dates) | Fully continuous business-day data; no missing values. Suitable as external market context. |
# | **stock_prices** | 0.00% | Converted `date` to datetime | Initially stored as object | 2021-01-04 → 2023-12-29 (780 unique dates) | Complete daily price data across tickers; aligned with market_indices for temporal analysis. |
# | **stock_prices_indicators** | ~0.47% overall (before fix) | Converted `date` to datetime; reindexed each ticker to full range; forward-filled gaps | Initially stored as object | 2021-01-04 → 2023-12-29 (780 unique dates after alignment) | Technical indicators had minor gaps (mostly due to rolling windows). Forward-filled values resolved missing points; dataset now consistent for modeling. |

# %% [markdown]
# ## Insight:
# Data Type Cleaning:
# All date and ipo_date columns were standardized to datetime format, resolving prior type inconsistencies.
#
# Temporal Consistency:
# All datasets now share the same trading-day range (780 business days), enabling synchronized time-series modeling.
#
# Minimal Missing Data:
# The few missing values in technical indicators were expected (rolling-window calculations).
# After forward-filling, continuity is restored with negligible data loss risk.
#
# Ready for Analysis:
# Datasets are well-structured for feature engineering, correlation studies, and predictive modeling (e.g., stock trend classification).

# %%
modeling_df = stock_prices_indicators.copy()

# %%
modeling_df.head()
# Out:
#         date  ticker    open    high     low   close     volume  \
# 0 2021-01-04  STK001  158.09  160.97  158.09  160.11   962644.0
# 1 2021-01-05  STK001  163.16  165.50  160.76  162.36  1312685.0
# 2 2021-01-06  STK001  161.89  162.51  160.94  161.78  1449177.0
# 3 2021-01-07  STK001  163.33  167.90  163.33  167.07  1534833.0
# 4 2021-01-08  STK001  168.20  168.20  164.12  165.68   848261.0
#
#    adjusted_close      sma_20      sma_50  ...  true_range  atr_14  \
# 0          160.11  160.110000  160.110000  ...        2.88   2.880
# 1          162.36  161.235000  161.235000  ...        5.39   4.135
# 2          161.78  161.416667  161.416667  ...        1.57   3.280
# 3          167.07  162.830000  162.830000  ...        6.12   3.990
# 4          165.68  163.400000  163.400000  ...        4.08   4.008
#
#    volume_sma_20  volume_ratio  momentum_10  momentum_20  price_to_sma_50  \
# 0      962644.00      1.000000    -0.044552     0.156698         0.000000
# 1     1137664.50      1.153842    -0.044552     0.156698         0.006977
# 2     1241502.00      1.167277    -0.044552     0.156698         0.002251
# 3     1314834.75      1.167320    -0.044552     0.156698         0.026039
# 4     1221520.00      0.694431    -0.044552     0.156698         0.013953
#
#    volatility_20  future_return_5d  trend_label
# 0       0.020763          0.026357      Uptrend
# 1       0.020763          0.018169     Sideways
# 2       0.012463         -0.012301     Sideways
# 3       0.018138         -0.061950    Downtrend
# 4       0.018663         -0.070196    Downtrend
#
# [5 rows x 31 columns]

# %%
modeling_df.isnull().sum()
# Out:
# date                0
# ticker              0
# open                0
# high                0
# low                 0
# close               0
# volume              0
# adjusted_close      0
# sma_20              0
# sma_50              0
# sma_200             0
# ema_12              0
# ema_26              0
# macd                0
# macd_signal         0
# macd_histogram      0
# rsi_14              0
# bb_middle           0
# bb_upper            0
# bb_lower            0
# bb_width            0
# true_range          0
# atr_14              0
# volume_sma_20       0
# volume_ratio        0
# momentum_10         0
# momentum_20         0
# price_to_sma_50     0
# volatility_20       0
# future_return_5d    0
# trend_label         0
# dtype: int64

# %%
# let save our clean data for modeling 
modeling_df.to_csv("../data/processed/modeling_df.csv", index=False)

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Price Trend Analysis:
# 1. Plot closing prices for 5 different stocks (one from each sector)
# 2. Identify uptrends, downtrends, and sideways periods visually
# 3. Calculate basic statistics: mean, median, std dev of returns

# %%
# Plot closing prices for 5 different stocks (one from each sector)
#Select one sample ticker from each sector
sample_tickers = (
    company_info
    .groupby('sector')['ticker']
    .first()   # pick the first ticker from each sector
    .values
)

plt.figure(figsize=(12,6))

# Plot one line per ticker
for ticker in sample_tickers:
    subset = stock_prices_indicators[
        stock_prices_indicators['ticker'] == ticker
    ].sort_values('date')  # ensure proper time order

    plt.plot(subset['date'], subset['close'], label=ticker)

plt.title('Closing Price Trends for Sample Stocks (One per Sector)')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.legend(title='Ticker')
plt.tight_layout()
plt.show()

# %%
# Visualize the uptrends, downtrends, and sideways period
plt.figure(figsize=(12,6))
colors = {'up': 'green', 'down': 'red', 'side': 'gray'}

for ticker in sample_tickers:
    df = stock_prices_indicators.query("ticker == @ticker").copy()
    df = df.sort_values('date')

    # Compute moving averages for trend detection
    df['SMA10'] = df['close'].rolling(10).mean()
    df['SMA30'] = df['close'].rolling(30).mean()

    # Define trend: up / down / sideways
    df['trend'] = np.where(df['SMA10'] > df['SMA30'], 'up',
                   np.where(df['SMA10'] < df['SMA30'], 'down', 'side'))

    # Plot base line
    plt.plot(df['date'], df['close'], color='lightgray', linewidth=1)

    # Overlay colored trend segments
    for t in df['trend'].unique():
        seg = df[df['trend'] == t]
        plt.plot(seg['date'], seg['close'], color=colors[t], linewidth=1.8)

    # Add ticker label near the latest point
    last_date = df['date'].iloc[-1]
    last_close = df['close'].iloc[-1]
    plt.text(last_date, last_close, f"  {ticker}", fontsize=9, weight='bold', 
             va='center', ha='left')

plt.title("Stock Price Trends by Sector (Up=Green, Down=Red, Sideways=Gray)")
plt.xlabel("Date")
plt.ylabel("Closing Price")
plt.tight_layout()
plt.show()

# %%
#Calculate basic statistics: mean, median, std dev of returns
# Ensure the data is sorted
stock_prices_indicators= stock_prices_indicators.sort_values(['ticker', 'date'])

# Compute daily returns per stock
stock_prices_indicators['daily_return'] = (
    stock_prices_indicators.groupby('ticker')['close'].pct_change()
)

# Calculate summary stats per ticker
return_stats = (
    stock_prices_indicators.groupby('ticker')['daily_return']
    .agg(['mean', 'median', 'std'])
    .reset_index()
    .rename(columns={'mean': 'Mean Return', 'median': 'Median Return', 'std': 'Std Deviation'})
)

# Display rounded results
return_stats = return_stats.round(4)
display(return_stats)
# Out:
#     ticker  Mean Return  Median Return  Std Deviation
# 0   STK001       0.0018         0.0016         0.0244
# 1   STK002      -0.0004         0.0000         0.0253
# 2   STK003       0.0001         0.0000         0.0253
# 3   STK004       0.0004         0.0000         0.0252
# 4   STK005       0.0007         0.0000         0.0215
# 5   STK006       0.0007         0.0000         0.0208
# 6   STK007      -0.0002         0.0000         0.0198
# 7   STK008       0.0007         0.0000         0.0206
# 8   STK009       0.0015         0.0013         0.0234
# 9   STK010       0.0004         0.0011         0.0227
# 10  STK011       0.0005         0.0005         0.0218
# 11  STK012       0.0006         0.0000         0.0233
# 12  STK013       0.0008         0.0009         0.0188
# 13  STK014       0.0015         0.0009         0.0189
# 14  STK015       0.0001         0.0004         0.0187
# 15  STK016      -0.0001         0.0000         0.0173
# 16  STK017       0.0009         0.0014         0.0296
# 17  STK018       0.0006         0.0008         0.0308
# 18  STK019      -0.0008         0.0009         0.0316
# 19  STK020       0.0008         0.0009         0.0316

# %% [markdown]
# ### Insight
# #### Interpretation of Summary Table
#
# Top Performers (Higher Mean Return):
# STK001 (0.0018) and STK014 (0.0015) show the strongest average daily gains (~0.18% and ~0.15% respectively).
# These stocks may be in stronger uptrends over time.
#
# Underperformers (Negative Mean Return):
# STK002 (-0.0004), STK007 (-0.0002), STK016 (-0.0001), and STK019 (-0.0008) have slightly negative means — indicating small daily declines on average.
#
# Volatility Insights:
# The most volatile stocks are STK017–STK020 (std ≈ 0.03) — they experience the largest daily swings.
# The most stable are STK013–STK016 (std ≈ 0.018–0.019) — they show smaller, steadier changes.
#
# Typical Returns (Median):
# Most medians are ≈ 0.0000–0.0010, meaning many stocks have flat or small positive daily movements — normal for liquid, stable assets.
#
# #### Overall Insight
# Most stocks show modest average daily gains (0.05–0.15%) and low-to-moderate volatility (std 0.02–0.03).
# A few (like STK017–STK020) are more volatile, while STK001 and STK014 stand out as consistent gainers.

# %% [markdown]
# #### Sector Comparison:
# 1. Calculate average returns by sector
# 2. Compare volatility across sectors
# 3. Visualize sector performance with box plots

# %%
# Merge returns with sector info
returns_with_sector = stock_prices_indicators.merge(
    company_info[['ticker', 'sector']], on='ticker', how='left'
)

# Compute mean and std of daily returns by sector
sector_stats = (
    returns_with_sector
    .groupby('sector')['daily_return']
    .agg(['mean', 'std'])
    .reset_index()
)

print("Sector Return Summary")
print(sector_stats)
# Out:
# Sector Return Summary
#        sector      mean       std
# 0    Consumer  0.000567  0.018475
# 1      Energy  0.000368  0.030906
# 2     Finance  0.000728  0.022796
# 3  Healthcare  0.000477  0.020667
# 4  Technology  0.000454  0.025060

# %%
# Compare volatility across sectors 
plt.figure(figsize=(8,5))
sns.barplot(
    data=sector_stats,
    x='sector',
    y='std',
    hue='sector',           # Explicitly use sector as hue
    palette='coolwarm',
    legend=False            # Turn off redundant legend
)
plt.title('Volatility (Standard Deviation of Returns) by Sector')
plt.ylabel('Standard Deviation')
plt.xlabel('Sector')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
# Visualize sector performance with box plots
plt.figure(figsize=(10,6))
sns.boxplot(
    data=returns_with_sector,
    x='sector',
    y='daily_return',
    hue='sector',
    legend=False, 
    palette='Set2'
)
plt.title('Distribution of Daily Returns by Sector')
plt.ylabel('Daily Return')
plt.xlabel('Sector')
plt.xticks(rotation=90)
plt.axhline(0, color='gray', linestyle='--', linewidth=1)
plt.show()

# %% [markdown]
# #### Insight
# Analysis of sector performance shows that the Finance and Consumer sectors achieved the highest average returns, indicating strong and consistent growth. The Consumer sector also recorded the lowest volatility, suggesting lower investment risk. In contrast, the Energy sector exhibited the highest volatility and the lowest average return, reflecting its sensitivity to market and commodity price fluctuations. Technology and Healthcare sectors maintained moderate returns with manageable risk levels, with Healthcare standing out for its relative stability, typical of defensive industries. Overall, Finance and Consumer sectors offered the best balance between risk and reward during the analysis period. From the boxplot visual, we can see that Energy sector has a wider box which indicate volatility.

# %% [markdown]
# ### Volume Analysis:
# 1. Plot volume patterns over time
# 2. Identify high-volume days and their relationship to price changes
# 3. Calculate correlation between volume and price movement

# %%
# Volume patterns over time 

# Plot volume patterns over time for sample tickers (one per sector)
plt.figure(figsize=(12,6))
for ticker in sample_tickers:
    subset = stock_prices_indicators[stock_prices_indicators['ticker'] == ticker]
    plt.plot(subset['date'], subset['volume'], label=ticker)

plt.title('Trading Volume Trends for Sample Stocks')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.legend(title='Ticker')
plt.show()

# %%
# Define high volume days (top 20% volume)
threshold = stock_prices["volume"].quantile(0.80)

high_volume_days = stock_prices[ stock_prices["volume"] > threshold ]

# Check if daily_return column exists
'daily_return' in high_volume_days.columns
# Out:
# False

# %%
# Merge high-volume days with daily returns
if 'daily_return' in high_volume_days.columns:
    high_volume_days = high_volume_days.drop(columns=['daily_return'])

high_volume_days = high_volume_days.merge(
    stock_prices_indicators[['ticker', 'date', 'daily_return']],
    on=['ticker', 'date'],
    how='left'
)
plt.figure(figsize=(8,5))
sns.boxplot(data=high_volume_days, x='ticker', y='daily_return', palette='viridis', hue='ticker')
plt.title('Price Movements on High-Volume Days')
plt.ylabel('Daily Return')
plt.xlabel('Ticker')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
# Correlation between volume and price movement
correlation = stock_prices_indicators[['volume', 'daily_return']].corr().iloc[0, 1]
print(f"Correlation between volume and returns: {correlation:.3f}")
# Out:
# Correlation between volume and returns: -0.014

# %%
# Correlation between volume and price movememt per sector 
sector_corr = stock_prices_indicators.groupby('ticker')[['volume', 'daily_return']].corr().iloc[0::2,-1].reset_index()
sector_corr.columns = ['ticker', 'drop', 'corr']
print(sector_corr.sort_values('corr'))
# Out:
#     ticker    drop      corr
# 14  STK015  volume -0.061889
# 2   STK003  volume -0.055096
# 1   STK002  volume -0.053726
# 17  STK018  volume -0.050858
# 16  STK017  volume -0.047139
# 18  STK019  volume -0.035347
# 5   STK006  volume -0.034655
# 19  STK020  volume -0.032464
# 0   STK001  volume -0.026372
# 4   STK005  volume -0.026070
# 15  STK016  volume -0.005988
# 11  STK012  volume  0.000712
# 8   STK009  volume  0.002033
# 10  STK011  volume  0.005476
# 9   STK010  volume  0.009798
# 13  STK014  volume  0.021998
# 12  STK013  volume  0.023603
# 6   STK007  volume  0.025705
# 3   STK004  volume  0.034247
# 7   STK008  volume  0.056334

# %% [markdown]
# ### Insight
# Across all tickers, the correlation between trading volume and daily returns remains weak, ranging from –0.06 to +0.06. This suggests that trading volume does not systematically predict price direction in the observed period. While a few stocks show slightly positive or negative tendencies, these relationships are too small to be meaningful. Therefore, price movements in this dataset appear largely independent of volume fluctuations.

# %% [markdown]
# ### Technical Indicator Exploration:
# 1. Visualize RSI patterns and identify overbought/oversold conditions
# 2. Plot MACD crossovers and their relationship to price trends
# 3. Examine Bollinger Band patterns

# %%
def compute_rsi(series, period=14):
    delta = series.diff()
    gain = delta.clip(lower=0)
    loss = -delta.clip(upper=0)
    avg_gain = gain.rolling(period).mean()
    avg_loss = loss.rolling(period).mean()
    rs = avg_gain / avg_loss
    rsi = 100 - (100 / (1 + rs))
    return rsi

# Compute RSI per ticker
modeling_df['rsi_14'] = modeling_df.groupby('ticker')['close'].transform(lambda x: compute_rsi(x))

# %%
# --- RSI Visualization (Overbought/Oversold) ---

# Select three ticker per sector
sample_tickers = company_info.groupby('sector')['ticker'].head(3).values

for ticker in sample_tickers:
    df = modeling_df[modeling_df['ticker'] == ticker].copy()
    
     
    # Plot RSI
    plt.figure(figsize=(12,4))
    plt.plot(df['date'], df['rsi_14'], label=f'RSI {ticker}', color='blue')
    plt.axhline(70, color='red', linestyle='--', label='Overbought')
    plt.axhline(30, color='green', linestyle='--', label='Oversold')
    plt.title(f"RSI(14) for {ticker} ({company_info.loc[company_info['ticker']==ticker,'sector'].values[0]})")
    plt.xlabel('Date')
    plt.ylabel('RSI')
    plt.legend()
    plt.show()

# %%
#Add MACD Signal columns

# Compute MACD 
if 'macd' not in df.columns:
    ema_12 = df['close'].ewm(span=12, adjust=False).mean()
    ema_26 = df['close'].ewm(span=26, adjust=False).mean()
    df['macd'] = ema_12 - ema_26
    df['macd_signal'] = df['macd'].ewm(span=9, adjust=False).mean()
   
# Plot MACD and price
plt.figure(figsize=(12,4))
plt.plot(df['date'], df['close'], label='Close Price', color='black')
plt.plot(df['date'], df['macd'], label='MACD', color='blue')
plt.plot(df['date'], df['macd_signal'], label='Signal', color='red')
plt.title(f"MACD and Close Price for {ticker} ({company_info.loc[company_info['ticker']==ticker,'sector'].values[0]})")
plt.xlabel('Date')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
# Bollinger Band patterns

# Compute Bollinger Bands 
if not {'bb_middle', 'bb_upper', 'bb_lower'}.issubset(df.columns):
    df['bb_middle'] = df['close'].rolling(20).mean()
    df['bb_std'] = df['close'].rolling(20).std()
    df['bb_upper'] = df['bb_middle'] + 2 * df['bb_std']
    df['bb_lower'] = df['bb_middle'] - 2 * df['bb_std']

# Plot
plt.figure(figsize=(12,5))
plt.plot(df['date'], df['close'], label='Close Price', color='blue')
plt.plot(df['date'], df['bb_middle'], label='Middle Band (SMA 20)', color='black', linestyle='--')
plt.plot(df['date'], df['bb_upper'], label='Upper Band', color='red', linestyle='--')
plt.plot(df['date'], df['bb_lower'], label='Lower Band', color='green', linestyle='--')
plt.fill_between(df['date'], df['bb_lower'], df['bb_upper'], color='grey', alpha=0.1)
    
plt.title(f"Bollinger Bands for {ticker} ({company_info.loc[company_info['ticker']==ticker,'sector'].values[0]})")
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %% [markdown]
# #### Insight
# Price touching or exceeding the upper band indicate overbought conditions while crossing below the lower band suggests oversold levels.
#
# The RSI(14) plot for the selected stock shows several peaks above 70, indicating overbought conditions followed by short-term price corrections. Occasional dips below 30 suggest oversold periods where the stock may have been undervalued before rebounding. Overall, the RSI pattern highlights alternating phases of buying and selling pressure, consistent with cyclical market behavior.

# %% [markdown]
# ### Correlation Analysis:
# 1. Create correlation heatmap of selected features
# 2. Identify highly correlated features (potential multicollinearity)

# %%
# correlation heatmap of selected features

# Select relevant numeric features for correlation analysis
features = [
    'close', 'sma_20', 'sma_50', 'price_to_sma_50', 
    'rsi_14', 'macd', 'macd_signal', 'atr_14', 'volatility_20', 
    'volume_ratio', 'momentum_10', 'momentum_20', 'bb_width'
]

corr_matrix = modeling_df[features].corr()

# Plot heatmap
plt.figure(figsize=(12,8))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap of Selected Features')
plt.show()

# %% [markdown]
# ### Correlation Summary of Technical Features
#
# Price and Moving Averages:
# close, sma_20, and sma_50 are very highly correlated (>0.97), indicating they move together closely.
# price_to_sma_50 has moderate correlation with rsi_14 (0.76) and macd (0.83), reflecting its relation to momentum indicators.
#
# Momentum Indicators:
# rsi_14 and momentum_10/20 show strong positive correlation (~0.80), confirming they capture similar price strength signals.
# macd and macd_signal are extremely correlated (0.96), as expected from the MACD calculation.
#
# Volatility Measures:
# atr_14 correlates strongly with bb_width (0.80) and with price/MAs (~0.94), indicating that volatility increases with price movement magnitude.
# volatility_20 has low correlations with most features except bb_width (0.24), showing it measures a slightly different aspect of price variability.
#
# Volume and Returns:
# volume_ratio shows nearly zero correlation with other features, suggesting volume-based signals are largely independent.
#
# Bollinger Bands
# bb_width is strongly correlated with atr_14 and moderately with close/MA features (~0.72), reflecting how bands widen during high volatility.
#
# ### Key Insights:
# Features like close, sma_20, and sma_50 are redundant, so including all in a model may cause multicollinearity.
# Momentum indicators (rsi_14, momentum_10/20, macd) are highly correlated; you might select 1–2 for modeling.
# Volume (volume_ratio) is independent, adding a unique dimension to predictive models.
# Volatility indicators (atr_14, bb_width) capture similar information, but volatility_20 is complementary.

# %%
from statsmodels.graphics.tsaplots import plot_acf

# %%
modeling_df['daily_return'] = modeling_df.groupby('ticker')['close'].pct_change()

# %%
# Autocorrelation (ACF) Analysis
ticker = modeling_df['ticker'].unique()[0]
df = modeling_df.query("ticker == @ticker")

plt.figure(figsize=(10,4))
plot_acf(df['daily_return'].dropna(), lags=30)
plt.title(f'Autocorrelation of Daily Returns ({ticker})')
plt.show()

# %%
# Show class distribution 
plt.figure(figsize=(6,4))
ax = sns.countplot(data=modeling_df, x='trend_label', palette='Set2')

# Add counts on each bar
for p in ax.patches:
    height = p.get_height()
    ax.annotate(
        f'{height}', 
        (p.get_x() + p.get_width() / 2, height),
        ha='center', 
        va='bottom'
    )

plt.title("Distribution of Trend Classes")
plt.xlabel("Trend")
plt.ylabel("Count")
plt.show()
# Out:
# C:\Users\phili\AppData\Local\Temp\ipykernel_7404\2280161249.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=modeling_df, x='trend_label', palette='Set2')

# %%
plt.figure(figsize=(6,6))

modeling_df['trend_label'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%',
    startangle=90,
    shadow=True,
    wedgeprops={'linewidth': 1, 'edgecolor': 'white'}
)

plt.title("Class Distribution of Trends")
plt.ylabel('')
plt.show()

# %%
# Return Distribution Analysis
plt.figure(figsize=(10,5))
sns.histplot(
   modeling_df['daily_return'].dropna(),
    kde=True,
    bins=50,
    color='purple'
)
plt.title('Distribution of Daily Returns')
plt.xlabel('Daily Return')
plt.ylabel('Frequency')
plt.show()

# %%
# Risk Analysis
sector_risk = (
    returns_with_sector
    .groupby('sector')['daily_return']
    .apply(lambda x: pd.Series({
        'VaR_95': x.quantile(0.05),
        'Expected_Shortfall': x[x < x.quantile(0.05)].mean()
    }))
)

display(sector_risk)
# Out:
# sector
# Consumer    VaR_95               -0.029897
#             Expected_Shortfall   -0.038682
# Energy      VaR_95               -0.050251
#             Expected_Shortfall   -0.066795
# Finance     VaR_95               -0.036675
#             Expected_Shortfall   -0.047849
# Healthcare  VaR_95               -0.033394
#             Expected_Shortfall   -0.043563
# Technology  VaR_95               -0.040989
#             Expected_Shortfall   -0.052871
# Name: daily_return, dtype: float64

# %%
#pip install seaborn --upgrade

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
# Sector Trend Strength 
returns_with_sector['rolling_30'] = (
    returns_with_sector
    .groupby('ticker')['daily_return']
    .transform(lambda x: x.rolling(30).mean())
)

plt.figure(figsize=(12,6))
sns.lineplot(data=returns_with_sector, x='date', y='rolling_30', hue='sector')
plt.title('30-Day Rolling Average Return by Sector')
plt.ylabel('Rolling Return (30D)')
plt.show()

# %% [markdown]
# ## Feature Selection & Data Preparation

# %%
# Initialize OBV column as float
modeling_df['obv'] = 0.0

for ticker, group in modeling_df.groupby('ticker'):
    obv = [0.0]  # start as float
    for i in range(1, len(group)):
        if group['close'].iloc[i] > group['close'].iloc[i-1]:
            obv.append(obv[-1] + float(group['volume'].iloc[i]))
        elif group['close'].iloc[i] < group['close'].iloc[i-1]:
            obv.append(obv[-1] - float(group['volume'].iloc[i]))
        else:
            obv.append(obv[-1])
    # Cast to float array before assignment
    modeling_df.loc[group.index, 'obv'] = np.array(obv, dtype=float)

# %%
## Add bb_position
modeling_df['bb_position'] = (
    (modeling_df['close'] - modeling_df['bb_lower']) /
    (modeling_df['bb_upper'] - modeling_df['bb_lower'])
)

# %%
period = 14

# Compute Stochastic %K per ticker
modeling_df['stochastic_k'] = (
    (modeling_df['close'] - 
     modeling_df.groupby('ticker')['low'].transform(lambda x: x.rolling(period).min())) /
    (modeling_df.groupby('ticker')['high'].transform(lambda x: x.rolling(period).max()) -
     modeling_df.groupby('ticker')['low'].transform(lambda x: x.rolling(period).min()))
)

# %%
modeling_df['return_lag_1'] = modeling_df['daily_return'].shift(1)
modeling_df['return_lag_2'] = modeling_df['daily_return'].shift(2)
modeling_df['return_lag_3'] = modeling_df['daily_return'].shift(3)

# %%
modeling_df['rsi_lag_1'] = modeling_df['rsi_14'].shift(1)
modeling_df['macd_lag_1'] = modeling_df['macd'].shift(1)
modeling_df['volatility_lag_1'] = modeling_df['volatility_20'].shift(1)

# %%
modeling_df.head(3)
# Out:
#         date  ticker    open    high     low   close     volume  \
# 0 2021-01-04  STK001  158.09  160.97  158.09  160.11   962644.0
# 1 2021-01-05  STK001  163.16  165.50  160.76  162.36  1312685.0
# 2 2021-01-06  STK001  161.89  162.51  160.94  161.78  1449177.0
#
#    adjusted_close      sma_20      sma_50  ...  daily_return        obv  \
# 0          160.11  160.110000  160.110000  ...           NaN        0.0
# 1          162.36  161.235000  161.235000  ...      0.014053  1312685.0
# 2          161.78  161.416667  161.416667  ...     -0.003572  -136492.0
#
#    bb_position  stochastic_k  return_lag_1  return_lag_2  return_lag_3  \
# 0    84.620453           NaN           NaN           NaN           NaN
# 1     0.676777           NaN           NaN           NaN           NaN
# 2     0.577757           NaN      0.014053           NaN           NaN
#
#    rsi_lag_1  macd_lag_1  volatility_lag_1
# 0        NaN         NaN               NaN
# 1        NaN    0.000000          0.020763
# 2        NaN    0.179487          0.020763
#
# [3 rows x 41 columns]

# %%
modeling_df.ffill(inplace=True)
modeling_df.bfill(inplace=True)
modeling_df.dropna(inplace=True)
modeling_df.head()
# Out:
#         date  ticker    open    high     low   close     volume  \
# 0 2021-01-04  STK001  158.09  160.97  158.09  160.11   962644.0
# 1 2021-01-05  STK001  163.16  165.50  160.76  162.36  1312685.0
# 2 2021-01-06  STK001  161.89  162.51  160.94  161.78  1449177.0
# 3 2021-01-07  STK001  163.33  167.90  163.33  167.07  1534833.0
# 4 2021-01-08  STK001  168.20  168.20  164.12  165.68   848261.0
#
#    adjusted_close      sma_20      sma_50  ...  daily_return        obv  \
# 0          160.11  160.110000  160.110000  ...      0.014053        0.0
# 1          162.36  161.235000  161.235000  ...      0.014053  1312685.0
# 2          161.78  161.416667  161.416667  ...     -0.003572  -136492.0
# 3          167.07  162.830000  162.830000  ...      0.032699  1398341.0
# 4          165.68  163.400000  163.400000  ...     -0.008320   550080.0
#
#    bb_position  stochastic_k  return_lag_1  return_lag_2  return_lag_3  \
# 0    84.620453      0.088026      0.014053      0.014053      0.014053
# 1     0.676777      0.088026      0.014053      0.014053      0.014053
# 2     0.577757      0.088026      0.014053      0.014053      0.014053
# 3     0.855317      0.088026     -0.003572      0.014053      0.014053
# 4     0.697858      0.088026      0.032699     -0.003572      0.014053
#
#    rsi_lag_1  macd_lag_1  volatility_lag_1
# 0  38.990826    0.000000          0.020763
# 1  38.990826    0.000000          0.020763
# 2  38.990826    0.179487          0.020763
# 3  38.990826    0.271798          0.012463
# 4  38.990826    0.763018          0.018138
#
# [5 rows x 41 columns]

# %%
# Features (exclude date and target)
target = 'trend_label'
modeling_df.dropna(subset=["trend_label"],inplace=True)
feature_cols = [c for c in modeling_df.columns if c not in ['date', 'trend_label']]

X = modeling_df[feature_cols]
y = modeling_df["trend_label"]

# %%
X.columns
# Out:
# Index(['ticker', 'open', 'high', 'low', 'close', 'volume', 'adjusted_close',
#        'sma_20', 'sma_50', 'sma_200', 'ema_12', 'ema_26', 'macd',
#        'macd_signal', 'macd_histogram', 'rsi_14', 'bb_middle', 'bb_upper',
#        'bb_lower', 'bb_width', 'true_range', 'atr_14', 'volume_sma_20',
#        'volume_ratio', 'momentum_10', 'momentum_20', 'price_to_sma_50',
#        'volatility_20', 'future_return_5d', 'daily_return', 'obv',
#        'bb_position', 'stochastic_k', 'return_lag_1', 'return_lag_2',
#        'return_lag_3', 'rsi_lag_1', 'macd_lag_1', 'volatility_lag_1'],
#       dtype='object')

# %%
# remove highly correlated features 
# Select numeric columns only
X_numeric = X.select_dtypes(include=['float64', 'int64'])

# Compute correlation matrix
corr_matrix = X_numeric.corr().abs()

# Upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

# Drop features with correlation > 0.8
to_drop = [col for col in upper.columns if any(upper[col] > 0.8)]
X_filtered = X_numeric.drop(columns=to_drop)

print("Dropped due to high correlation:", to_drop)
print("Remaining features:", X_filtered.columns.tolist())
# Out:
# Dropped due to high correlation: ['high', 'low', 'close', 'adjusted_close', 'sma_20', 'sma_50', 'sma_200', 'ema_12', 'ema_26', 'macd_signal', 'bb_middle', 'bb_upper', 'bb_lower', 'atr_14', 'price_to_sma_50', 'stochastic_k', 'rsi_lag_1', 'macd_lag_1', 'volatility_lag_1']
# Remaining features: ['open', 'volume', 'macd', 'macd_histogram', 'rsi_14', 'bb_width', 'true_range', 'volume_sma_20', 'volume_ratio', 'momentum_10', 'momentum_20', 'volatility_20', 'future_return_5d', 'daily_return', 'obv', 'bb_position', 'return_lag_1', 'return_lag_2', 'return_lag_3']

# %%
X_filtered.drop(columns=['future_return_5d'], inplace=True)

# %%
remaining_features = X_filtered.columns.to_list()

print(remaining_features)
# Out:
# ['open', 'volume', 'macd', 'macd_histogram', 'rsi_14', 'bb_width', 'true_range', 'volume_sma_20', 'volume_ratio', 'momentum_10', 'momentum_20', 'volatility_20', 'daily_return', 'obv', 'bb_position', 'return_lag_1', 'return_lag_2', 'return_lag_3']

# %%
# Include 'date' in selected columns for temporal split
modeling_data = modeling_df[['date'] + remaining_features + [target]].copy()

# %%
# Check if the target feature have missing value 
y.isna().sum()
# Out:
# np.int64(0)

# %%
# --- Train-Test Split (temporal) ---
modeling_df = modeling_df.sort_values('date')  # now 'date' exists

# Time-based split
split_idx = int(len(modeling_df) * 0.7)
train_df = modeling_df.iloc[:split_idx]
test_df = modeling_df.iloc[split_idx:]

print(f"Training set: {train_df.shape[0]} rows")
print(f"Test set: {test_df.shape[0]} rows")
print(f"Features: {remaining_features}")

# X and y split
X_train = train_df[remaining_features].copy()
y_train = train_df[target].copy()

X_test = test_df[remaining_features].copy()
y_test = test_df[target].copy()
# Out:
# Training set: 10920 rows
# Test set: 4680 rows
# Features: ['open', 'volume', 'macd', 'macd_histogram', 'rsi_14', 'bb_width', 'true_range', 'volume_sma_20', 'volume_ratio', 'momentum_10', 'momentum_20', 'volatility_20', 'daily_return', 'obv', 'bb_position', 'return_lag_1', 'return_lag_2', 'return_lag_3']

# %% [markdown]
# ### Baseline Model

# %%
from sklearn.preprocessing import LabelEncoder

# %%
 #Ensure all features are numeric
print("Checking feature dtypes:")
print(X_train.dtypes)
# Out:
# Checking feature dtypes:
# open              float64
# volume            float64
# macd              float64
# macd_histogram    float64
# rsi_14            float64
# bb_width          float64
# true_range        float64
# volume_sma_20     float64
# volume_ratio      float64
# momentum_10       float64
# momentum_20       float64
# volatility_20     float64
# daily_return      float64
# obv               float64
# bb_position       float64
# return_lag_1      float64
# return_lag_2      float64
# return_lag_3      float64
# dtype: object

# %%
# If target is categorical, encode it
if y_train.dtype == 'object' or y_train.dtype.name == 'category':
    le = LabelEncoder()
    y_train = le.fit_transform(y_train)
    y_test = le.transform(y_test)

# %%
# Check class distribution
print("Class distribution in training set:")
print(pd.Series(y_train).value_counts())
# Out:
# Class distribution in training set:
# 2    3847
# 0    3685
# 1    3388
# Name: count, dtype: int64

# %%
le.classes_
# Out:
# array(['Downtrend', 'Sideways', 'Uptrend'], dtype=object)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

# %%
# Initialize model and add class weight so it can predict the sideways
model = LogisticRegression(max_iter=1000, class_weight="balanced")

# %%
# Fit model
model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000)

# %%
# Predict on test set
y_pred = model.predict(X_test_scaled)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
# Accuracy
acc = accuracy_score(y_test, y_pred)
print(f"Test Accuracy: {acc:.2f}")
# Out:
# Test Accuracy: 0.36

# %%
# Classification Report
report = classification_report(y_test, y_pred, target_names=le.classes_)
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#    Downtrend       0.36      0.23      0.28      1380
#     Sideways       0.36      0.71      0.48      1581
#      Uptrend       0.37      0.16      0.22      1719
#
#     accuracy                           0.36      4680
#    macro avg       0.36      0.36      0.33      4680
# weighted avg       0.36      0.36      0.32      4680

# %%
# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=le.classes_, yticklabels=le.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
print(cm)
# Out:
# [[ 312  836  232]
#  [ 241 1122  218]
#  [ 325 1126  268]]

# %% [markdown]
# ## Improved Model Development
# ####  Build a more sophisticated model to improve prediction accuracy

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=100, max_depth=20, random_state=42, class_weight='balanced' )

# %%
rf.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=20, random_state=42)

# %%
rf_preds = rf.predict(X_test_scaled)

# %%
print("Random Forest (Initial) Accuracy:", accuracy_score(y_test, rf_preds))
# Out:
# Random Forest (Initial) Accuracy: 0.3467948717948718

# %%
print(classification_report(y_test, rf_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.30      0.29      0.29      1380
#            1       0.37      0.31      0.34      1581
#            2       0.36      0.42      0.39      1719
#
#     accuracy                           0.35      4680
#    macro avg       0.34      0.34      0.34      4680
# weighted avg       0.35      0.35      0.35      4680

# %%
rf_cm = confusion_matrix(y_test, rf_preds)
plt.figure(figsize=(6,5))
sns.heatmap(rf_cm, annot=True, fmt='g', cmap="coolwarm", xticklabels=le.classes_, yticklabels=le.classes_)
plt.xlabel("Predicted")
plt.ylabel=("Actual")
plt.title('Confusion Matrix')
plt.show()

# %%
print(rf_cm)
# Out:
# [[396 352 632]
#  [430 497 654]
#  [512 477 730]]

# %%
#!pip install xgboost

# %%
from xgboost import XGBClassifier

xg_model = XGBClassifier(
    n_estimators=300,
    max_depth=6,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    objective='multi:softmax',
    random_state=42
)

xg_model.fit(X_train_scaled, y_train)
xg_preds = model.predict(X_test_scaled)

# %%
print(classification_report(y_test, xg_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.36      0.23      0.28      1380
#            1       0.36      0.71      0.48      1581
#            2       0.37      0.16      0.22      1719
#
#     accuracy                           0.36      4680
#    macro avg       0.36      0.36      0.33      4680
# weighted avg       0.36      0.36      0.32      4680

# %% [markdown]
# #### Apply hypermeter tuning - GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {"n_estimators": [50, 100, 200],
"max_depth": [10, 20, 30, None],
"min_samples_split": [2, 5, 10]
}

# %%
rf_tuner = GridSearchCV(
    estimator=RandomForestClassifier(random_state=42),
    param_grid=param_grid,
    cv=3,
    scoring="accuracy",
    n_jobs=-1,
    verbose=2
)

# %%
rf_tuner.fit(X_train_scaled, y_train)
# Out:
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# GridSearchCV(cv=3, estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [10, 20, 30, None],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 100, 200]},
#              scoring='accuracy', verbose=2)

# %%
print("Best Parameters:", rf_tuner.best_params_)
print("Best CV Accuracy:", rf_tuner.best_score_)
# Out:
# Best Parameters: {'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 100}
# Best CV Accuracy: 0.34432234432234426

# %%
#Keep tuned model 
best_rf = rf_tuner.best_estimator_

# %%
rf_tuned_preds = best_rf.predict(X_test_scaled)

# %%
print("Tuned Random Forest Accuracy:", accuracy_score(y_test, rf_tuned_preds))
print(classification_report(y_test, rf_tuned_preds))
# Out:
# Tuned Random Forest Accuracy: 0.36773504273504276
#               precision    recall  f1-score   support
#
#            0       0.33      0.22      0.26      1380
#            1       0.38      0.33      0.36      1581
#            2       0.37      0.52      0.43      1719
#
#     accuracy                           0.37      4680
#    macro avg       0.36      0.36      0.35      4680
# weighted avg       0.36      0.37      0.36      4680

# %%
rf_tuned_cm = confusion_matrix(y_test, rf_tuned_preds)
plt.figure(figsize=(6,5))
sns.heatmap(rf_tuned_cm, annot=True, fmt='g', cmap="coolwarm", xticklabels=le.classes_, yticklabels=le.classes_)
plt.xlabel("Predicted")
plt.ylabel=("Actual")
plt.title('Confusion Matrix')
plt.savefig(
    "../visuals/model_performance/confusion_matrix_rf_tuned.png",
    dpi=300,
    bbox_inches="tight"
)
plt.show()

# %%
print(rf_tuned_cm)
# Out:
# [[300 360 720]
#  [265 528 788]
#  [336 490 893]]

# %%
from sklearn.metrics import f1_score

# %%
comparison = pd.DataFrame({
    "Model": ["Logistic Regression", "Random Forest (Initial)", "Random Forest (Tuned)"],
    "Accuracy": [
        accuracy_score(y_test, y_pred),
        accuracy_score(y_test, rf_preds),
        accuracy_score(y_test, rf_tuned_preds)
    ],
    "F1 Score": [
        f1_score(y_test, y_pred, average='weighted'),
        f1_score(y_test, rf_preds, average='weighted'),
        f1_score(y_test, rf_tuned_preds, average='weighted')
    ]
}).round(2)

comparison
# Out:
#                      Model  Accuracy  F1 Score
# 0      Logistic Regression      0.36      0.32
# 1  Random Forest (Initial)      0.35      0.35
# 2    Random Forest (Tuned)      0.37      0.36

# %%
fig, ax = plt.subplots()
ax.axis('off')

table_data = [
    ["Logistic Regression", 0.36, 0.32],
    ["Random Forest (Initial)", 0.35, 0.35],
    ["Random Forest (Tuned)", 0.37, 0.36],
]

col_labels = ["Model", "Accuracy", "F1 Score"]

ax.table(cellText=table_data, colLabels=col_labels, loc='center')

plt.savefig(
    "../visuals/summary/comparison_table.png",
    dpi=300,
    bbox_inches="tight"
)
plt.show()

# %% [markdown]
# ## Feature Importance

# %%
# Create DataFrame of Feature Importance
fi_df = pd.DataFrame({
    "feature": X_train.columns,
    "importance": rf.feature_importances_
})

# Sort by importance
fi_df = fi_df.sort_values("importance", ascending=False)
print(fi_df.head(10))
# Out:
#            feature  importance
# 11   volatility_20    0.071271
# 0             open    0.066508
# 13             obv    0.065812
# 7    volume_sma_20    0.061993
# 2             macd    0.058676
# 5         bb_width    0.058407
# 3   macd_histogram    0.056816
# 4           rsi_14    0.055239
# 10     momentum_20    0.053187
# 9      momentum_10    0.052653

# %%
# Select top 10 features
top10 = fi_df.head(10).sort_values("importance", ascending=True)

plt.figure(figsize=(8, 5))
plt.barh(top10['feature'], top10['importance'])
plt.title("Top 10 Feature Importances")
plt.xlabel("Importance")
plt.tight_layout()
plt.show()

# %% [markdown]
# Summary of What the Model Is Really Doing.
# My model cares mostly about 3 things:
#
# 1. Trend direction indicators
#     MACD
#     MACD histogram
#     Momentum_20
#     RSI_14
#     Return_lag_1
# These help the model understand where price is moving.
#
# 2. Volatility indicators
#     volatility_20
#     bb_width
# The model uses these to understand trend strength and breakout potential.
#
# 3. Volume indicators
#     OBV
#     volume_sma_20
# The model checks whether volume supports the trend.

# %% [markdown]
# ## SHAP

# %%
# %pip install Shap

# %%
import shap

# %%
explainer = shap.TreeExplainer(rf)
shap_values = explainer.shap_values(X_test)

# %%
# Summary plot
shap.summary_plot(shap_values, X_test)

# %%
# let train and evaluate another random forest model with these features 
X_train_top = X_train[fi_df]
X_test_top  = X_test[fi_df]

# %%
# random forest with reduced featuures 
rf_top = RandomForestClassifier(
    n_estimators=200,
    max_depth=None,
    random_state=42, class_weight='balanced'
)

# %%
rf_top.fit(X_train_top, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=200,
#                        random_state=42)

# %%
y_pred_top = rf_top.predict(X_test_top)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred_top))
print("\nClassification Report:\n", classification_report(y_test, y_pred_top))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred_top))
# Out:
# Accuracy: 0.2948717948717949
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.29      1.00      0.46      1380
#            1       0.00      0.00      0.00      1581
#            2       0.00      0.00      0.00      1719
#
#     accuracy                           0.29      4680
#    macro avg       0.10      0.33      0.15      4680
# weighted avg       0.09      0.29      0.13      4680
#
#
# Confusion Matrix:
#  [[1380    0    0]
#  [1581    0    0]
#  [1719    0    0]]
# c:\Users\phili\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\phili\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\phili\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import os
os.makedirs("saved_models", exist_ok=True)

# %%
import pickle

# Save Label Encoder
with open("saved_models/label_encoder.pkl", "wb") as f:
    pickle.dump(le, f)

# Save Scaler
with open("saved_models/scaler.pkl", "wb") as f:
    pickle.dump(scaler, f)

print("Encoder and Scaler saved successfully.")
# Out:
# Encoder and Scaler saved successfully.

# %% [markdown]
# ### Summary

# %%
# Confusion matrices
cm_logreg = np.array([
    [312, 836, 232],
    [241, 1122, 218],
    [325, 1126, 268]
])

cm_rf = np.array([
    [396, 352, 632],
    [430, 497, 654],
    [512, 477, 730]
])

cm_rf_tuned = np.array([
    [300, 360, 720],
    [265, 528, 788],
    [336, 490, 893]
])

# Labels
labels = ["Downtrend", "Sideways", "Uptrend"]

# Create subplots
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Logistic Regression
sns.heatmap(
    cm_logreg, annot=True, fmt="d", cmap="Blues",
    xticklabels=labels, yticklabels=labels, ax=axes[0]
)
axes[0].set_title("Logistic Regression (Baseline)")
axes[0].set_xlabel("Predicted")
axes[0].set_ylabel("Actual")

# Random Forest (Initial)
sns.heatmap(
    cm_rf, annot=True, fmt="d", cmap="Blues",
    xticklabels=labels, yticklabels=labels, ax=axes[1]
)
axes[1].set_title("Random Forest (Initial)")
axes[1].set_xlabel("Predicted")
axes[1].set_ylabel("")

# Random Forest (Tuned)
sns.heatmap(
    cm_rf_tuned, annot=True, fmt="d", cmap="Blues",
    xticklabels=labels, yticklabels=labels, ax=axes[2]
)
axes[2].set_title("Random Forest (Tuned)")
axes[2].set_xlabel("Predicted")
axes[2].set_ylabel("")

plt.suptitle("Prediction vs Actual — Model Comparison", fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.95])

plt.savefig(
    "../visuals/summary/prediction_vs_actual.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
# Create performance summary DataFrame
performance_df = pd.DataFrame({
    "Model": [
        "Logistic Regression",
        "Random Forest (Initial)",
        "Random Forest (Tuned)"
    ],
    "Accuracy": [0.36, 0.35, 0.37],
    "F1 Score": [0.32, 0.35, 0.36]
})

# Sort by F1 Score (better metric for imbalance)
performance_df = performance_df.sort_values(
    by="F1 Score", ascending=False
)

# Plot table
fig, ax = plt.subplots(figsize=(7, 2.5))
ax.axis("off")

table = ax.table(
    cellText=performance_df.values,
    colLabels=performance_df.columns,
    loc="center",
    cellLoc="center"
)

table.scale(1, 1.6)
plt.title("Overall Model Performance Summary")

plt.savefig(
    "../visuals/summary/overall_performance_table.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# The summary visuals provide a consolidated view of model performance. The prediction versus actual heatmap highlights the model’s tendency to favor the dominant trend class, reflecting the noisy nature of financial data. The overall performance table confirms that the tuned Random Forest model achieves the best balance between accuracy and F1 score compared to the baseline model.
